# %%
import pandas as pd

# %%
df= pd.read_csv("lego_sets.csv")

# %%
df.head()
# Out:
#   Miaka  list_price  piece_count  play_star_rating  \
# 0  6-12       29.99        277.0               4.0
# 1  6-12       19.99        168.0               4.0
# 2  6-12       12.99         74.0               4.3
# 3   12+       99.99       1032.0               3.6
# 4   12+       79.99        744.0               3.2
#
#                                            prod_desc  \
# 0  Catapult into action and take back the eggs fr...
# 1  Launch a flying attack and rescue the eggs fro...
# 2  Chase the piggy with lightning-fast Chuck and ...
# 3  Explore the architecture of the United States ...
# 4  Recreate the Solomon R. Guggenheim Museum® wit...
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
# 2  Pitch speedy bird Chuck against the Piggy Car....              Easy
# ...

# %%
df.shape
# Out:
# (10872, 13)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Miaka  list_price  piece_count  play_star_rating  \
# 0      6-12     29.9900        277.0               4.0
# 1      6-12     19.9900        168.0               4.0
# 2      6-12     12.9900         74.0               4.3
# 3       12+     99.9900       1032.0               3.6
# 4       12+     79.9900        744.0               3.2
# ...     ...         ...          ...               ...
# 12234  7-14     42.6878        254.0               4.2
# 12236  7-14     30.4878        204.0               4.1
# 12237  7-14     30.4878        201.0               4.1
# 12238  6-12     18.2878        141.0               4.0
# 12239  6-12     18.2878        124.0               4.5
#
#                                                prod_desc  \
# 0      Catapult into action and take back the eggs fr...
# 1      Launch a flying attack and rescue the eggs fro...
# 2      Chase the piggy with lightning-fast Chuck and ...
# ...

# %%
df.describe()
# Out:
#          list_price   piece_count  play_star_rating  star_rating  \
# count  10872.000000  10872.000000       9350.000000  9463.000000
# mean      67.298403    503.849614          4.359914     4.511212
# std       94.664030    831.159196          0.615536     0.516310
# min        2.272400      1.000000          1.000000     1.800000
# 25%       21.899000     97.000000          4.000000     4.300000
# 50%       36.587800    223.000000          4.500000     4.600000
# 75%       73.187800    556.000000          4.800000     5.000000
# max     1104.870000   7541.000000          5.000000     5.000000
#
#        val_star_rating      prod_id1
# count      9330.000000  1.087200e+04
# mean          4.214630  6.181800e+04
# std           0.664763  1.736231e+05
# min           1.000000  6.300000e+02
# 25%           4.000000  2.112300e+04
# 50%           4.300000  4.207400e+04
# 75%           4.700000  7.124800e+04
# max           5.000000  2.000431e+06

# %%
# Median of star_rating
df['star_rating'].median()
# Out:
# 4.6

# %%
# Number of unique play_star_rating
df['play_star_rating'].nunique()
# Out:
# 30

# %%
# Standard deviation of list_price
df['list_price'].std()
# Out:
# 94.66402964178242

# %%
# Total number of pieces (basic version)
df['piece_count'].sum()
# Out:
# 5477853.0

# %%
# 90% quantile of all numerical columns
df.quantile(0.9)
# Out:
# list_price            143.952
# piece_count          1098.000
# play_star_rating        5.000
# star_rating             5.000
# val_star_rating         5.000
# prod_id1            75827.000
# Name: 0.9, dtype: float64

# %%
# Unique values
df['review_difficulty'].unique()
# Out:
# array(['Average', 'Easy', 'Challenging', 'Very Easy', nan,
#        'Very Challenging'], dtype=object)

# %%
# Value counts
df['review_difficulty'].value_counts()
# Out:
# Easy                3816
# Average             3380
# Challenging          995
# Very Easy            934
# Very Challenging       8
# Name: review_difficulty, dtype: int64

# %%
string_df = df.applymap(lambda x: str(x))
string_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10872 entries, 0 to 12239
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Miaka              10872 non-null  object
#  1   list_price         10872 non-null  object
#  2   piece_count        10872 non-null  object
#  3   play_star_rating   10872 non-null  object
#  4   prod_desc          10872 non-null  object
#  5   prod_long_desc     10872 non-null  object
#  6   review_difficulty  10872 non-null  object
#  7   set_name           10872 non-null  object
#  8   star_rating        10872 non-null  object
#  9   theme_name         10872 non-null  object
#  10  val_star_rating    10872 non-null  object
#  11  country            10872 non-null  object
#  12  prod_id1           10872 non-null  object
# dtypes: object(13)
# memory usage: 1.2+ MB

# %%
df.tail()
# Out:
#        ages  list_price  num_reviews  piece_count  play_star_rating  \
# 12256  7-14     36.5878          6.0        341.0               4.4
# 12257  7-14     24.3878          8.0        217.0               4.1
# 12258  7-14     24.3878         18.0        233.0               4.6
# 12259  6-14     12.1878          1.0         48.0               5.0
# 12260  6-14     12.1878         11.0        109.0               4.5
#
#                                                prod_desc  prod_id  \
# 12256  Protect NINJAGO® City from flying Manta Ray Bo...  70609.0
# 12257         Stop a Piranha Attack with Kai and Misako!  70629.0
# 12258   Stop a crime in the NINJAGO® City street market!  70607.0
# 12259  Achieve Spinjitzu greatness with the Green Ninja!  70628.0
# 12260  Practice your Spinjitzu skills with Kai and Zane!  70606.0
#
#                                           prod_long_desc review_difficulty  \
# 12256  Help Cole save Shen-Li in this cool THE LEGO® ...              Easy
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of        ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0      6-12     29.9900          2.0        277.0               4.0
# 1      6-12     19.9900          2.0        168.0               4.0
# 2      6-12     12.9900         11.0         74.0               4.3
# 3       12+     99.9900         23.0       1032.0               3.6
# 4       12+     79.9900         14.0        744.0               3.2
# ...     ...         ...          ...          ...               ...
# 12256  7-14     36.5878          6.0        341.0               4.4
# 12257  7-14     24.3878          8.0        217.0               4.1
# 12258  7-14     24.3878         18.0        233.0               4.6
# 12259  6-14     12.1878          1.0         48.0               5.0
# 12260  6-14     12.1878         11.0        109.0               4.5
#
#                                                prod_desc  prod_id  \
# ...

# %%
df.iloc[0]
# Out:
# ages                                                              6-12
# list_price                                                       29.99
# num_reviews                                                          2
# piece_count                                                        277
# play_star_rating                                                     4
# prod_desc            Catapult into action and take back the eggs fr...
# prod_id                                                          75823
# prod_long_desc       Use the staircase catapult to launch Red into ...
# review_difficulty                                              Average
# set_name                                         Bird Island Egg Heist
# star_rating                                                        4.5
# theme_name                                                Angry Birds™
# val_star_rating                                                      4
# ...

# %%
df.iloc[1:5]
# Out:
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 1  6-12       19.99          2.0        168.0               4.0
# 2  6-12       12.99         11.0         74.0               4.3
# 3   12+       99.99         23.0       1032.0               3.6
# 4   12+       79.99         14.0        744.0               3.2
#
#                                            prod_desc  prod_id  \
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
# 2  Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3  Explore the architecture of the United States ...  21030.0
# 4  Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
#
#                                       prod_long_desc review_difficulty  \
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
# 2  Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3  Discover the architectural secrets of the icon...           Average
# ...

# %%
df.loc[df['piece_count']<100].head()
# Out:
#     ages  list_price  num_reviews  piece_count  play_star_rating  \
# 2   6-12       12.99         11.0         74.0               4.3
# 23   10+        9.99          2.0         91.0               3.0
# 35   10+        9.99          5.0         89.0               3.2
# 38   10+        9.99         11.0         91.0               3.8
# 39   10+        9.99          8.0         96.0               4.0
#
#                                             prod_desc  prod_id  \
# 2   Chase the piggy with lightning-fast Chuck and ...  75821.0
# 23  Join the Resistance with a LEGO® BrickHeadz co...  41485.0
# 35  Learn the way of the ninja with LEGO® BrickHea...  41488.0
# 38  Celebrate THE LEGO® BATMAN MOVIE with a LEGO B...  41585.0
# 39  Stand your ground with your own LEGO® BrickHea...  41590.0
#
#                                        prod_long_desc review_difficulty  \
# 2   Pitch speedy bird Chuck against the Piggy Car....              Easy
# ...

# %%
df= df.rename(columns={"ages":"Miaka"})
df
# Out:
#       Miaka  list_price  num_reviews  piece_count  play_star_rating  \
# 0      6-12     29.9900          2.0        277.0               4.0
# 1      6-12     19.9900          2.0        168.0               4.0
# 2      6-12     12.9900         11.0         74.0               4.3
# 3       12+     99.9900         23.0       1032.0               3.6
# 4       12+     79.9900         14.0        744.0               3.2
# ...     ...         ...          ...          ...               ...
# 12256  7-14     36.5878          6.0        341.0               4.4
# 12257  7-14     24.3878          8.0        217.0               4.1
# 12258  7-14     24.3878         18.0        233.0               4.6
# 12259  6-14     12.1878          1.0         48.0               5.0
# 12260  6-14     12.1878         11.0        109.0               4.5
#
#                                                prod_desc  prod_id  \
# 0      Catapult into action and take back the eggs fr...  75823.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Miaka              12261 non-null  object
#  1   list_price         12261 non-null  float64
#  2   num_reviews        10641 non-null  float64
#  3   piece_count        12261 non-null  float64
#  4   play_star_rating   10486 non-null  float64
#  5   prod_desc          11884 non-null  object
#  6   prod_id            12261 non-null  float64
#  7   prod_long_desc     12261 non-null  object
#  8   review_difficulty  10206 non-null  object
#  9   set_name           12261 non-null  object
#  10  star_rating        10641 non-null  float64
#  11  theme_name         12258 non-null  object
#  12  val_star_rating    10466 non-null  float64
#  13  country            12261 non-null  object
# dtypes: float64(7), object(7)
# memory usage: 1.3+ MB

# %%
df['prod_id1']=df['prod_id'].astype("int")
df
# Out:
#       Miaka  list_price  num_reviews  piece_count  play_star_rating  \
# 0      6-12     29.9900          2.0        277.0               4.0
# 1      6-12     19.9900          2.0        168.0               4.0
# 2      6-12     12.9900         11.0         74.0               4.3
# 3       12+     99.9900         23.0       1032.0               3.6
# 4       12+     79.9900         14.0        744.0               3.2
# ...     ...         ...          ...          ...               ...
# 12256  7-14     36.5878          6.0        341.0               4.4
# 12257  7-14     24.3878          8.0        217.0               4.1
# 12258  7-14     24.3878         18.0        233.0               4.6
# 12259  6-14     12.1878          1.0         48.0               5.0
# 12260  6-14     12.1878         11.0        109.0               4.5
#
#                                                prod_desc  prod_id  \
# 0      Catapult into action and take back the eggs fr...  75823.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Miaka              12261 non-null  object
#  1   list_price         12261 non-null  float64
#  2   num_reviews        10641 non-null  float64
#  3   piece_count        12261 non-null  float64
#  4   play_star_rating   10486 non-null  float64
#  5   prod_desc          11884 non-null  object
#  6   prod_id            12261 non-null  float64
#  7   prod_long_desc     12261 non-null  object
#  8   review_difficulty  10206 non-null  object
#  9   set_name           12261 non-null  object
#  10  star_rating        10641 non-null  float64
#  11  theme_name         12258 non-null  object
#  12  val_star_rating    10466 non-null  float64
#  13  country            12261 non-null  object
#  14  prod_id1           12261 non-null  int64
# dtypes: float64(7), int64(1), object(7)
# ...

# %%
df.duplicated().sum()
df.duplicated
# Out:
# <bound method DataFrame.duplicated of       Miaka  list_price  num_reviews  piece_count  play_star_rating  \
# 0      6-12     29.9900          2.0        277.0               4.0
# 1      6-12     19.9900          2.0        168.0               4.0
# 2      6-12     12.9900         11.0         74.0               4.3
# 3       12+     99.9900         23.0       1032.0               3.6
# 4       12+     79.9900         14.0        744.0               3.2
# ...     ...         ...          ...          ...               ...
# 12256  7-14     36.5878          6.0        341.0               4.4
# 12257  7-14     24.3878          8.0        217.0               4.1
# 12258  7-14     24.3878         18.0        233.0               4.6
# 12259  6-14     12.1878          1.0         48.0               5.0
# 12260  6-14     12.1878         11.0        109.0               4.5
#
#                                                prod_desc  prod_id  \
# ...

# %%
df = df.drop_duplicates()

# %%
df.duplicated().value_counts()
# Out:
# False    10872
# dtype: int64

# %%
df.drop_duplicates().value_counts()
# Out:
# Miaka  list_price  num_reviews  piece_count  play_star_rating  prod_desc                                                    prod_id  prod_long_desc                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12234    False
# 12236    False
# 12237    False
# 12238    False
# 12239    False
# Length: 10872, dtype: bool

# %%
df = df.drop("num_reviews",axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10872 entries, 0 to 12239
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Miaka              10872 non-null  object
#  1   list_price         10872 non-null  float64
#  2   piece_count        10872 non-null  float64
#  3   play_star_rating   9350 non-null   float64
#  4   prod_desc          10495 non-null  object
#  5   prod_id            10872 non-null  float64
#  6   prod_long_desc     10872 non-null  object
#  7   review_difficulty  9133 non-null   object
#  8   set_name           10872 non-null  object
#  9   star_rating        9463 non-null   float64
#  10  theme_name         10869 non-null  object
#  11  val_star_rating    9330 non-null   float64
#  12  country            10872 non-null  object
#  13  prod_id1           10872 non-null  int64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 1.2+ MB

# %%
df = df.drop("prod_id", axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10872 entries, 0 to 12239
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Miaka              10872 non-null  object
#  1   list_price         10872 non-null  float64
#  2   piece_count        10872 non-null  float64
#  3   play_star_rating   9350 non-null   float64
#  4   prod_desc          10495 non-null  object
#  5   prod_long_desc     10872 non-null  object
#  6   review_difficulty  9133 non-null   object
#  7   set_name           10872 non-null  object
#  8   star_rating        9463 non-null   float64
#  9   theme_name         10869 non-null  object
#  10  val_star_rating    9330 non-null   float64
#  11  country            10872 non-null  object
#  12  prod_id1           10872 non-null  int64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 1.2+ MB
